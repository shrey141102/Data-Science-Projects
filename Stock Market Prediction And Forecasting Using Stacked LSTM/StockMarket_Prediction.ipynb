# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading the Dataset

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv")

# %%
dataset.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
dataset.tail()
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %%
dataset.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
dataset.isnull()
# Out:
#        Date   Open   High    Low   Last  Close  Total Trade Quantity  \
# 0     False  False  False  False  False  False                 False
# 1     False  False  False  False  False  False                 False
# 2     False  False  False  False  False  False                 False
# 3     False  False  False  False  False  False                 False
# 4     False  False  False  False  False  False                 False
# ...     ...    ...    ...    ...    ...    ...                   ...
# 2030  False  False  False  False  False  False                 False
# 2031  False  False  False  False  False  False                 False
# 2032  False  False  False  False  False  False                 False
# 2033  False  False  False  False  False  False                 False
# 2034  False  False  False  False  False  False                 False
#
#       Turnover (Lacs)
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 2030            False
# 2031            False
# 2032            False
# 2033            False
# 2034            False
#
# [2035 rows x 8 columns]

# %% [markdown]
# # Sorting the Data

# %%
dataset['Date']=pd.to_datetime(dataset['Date'])
print(type(dataset.Date[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df = dataset.sort_values(by='Date')
df.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %% [markdown]
# # Data Visualization

# %%
plt.plot(df['Close'])

# %%
dff=df['Close']
dff
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %% [markdown]
# # Min Max Scaler

# %%
scaler=MinMaxScaler(feature_range=(0,1))
dff = scaler.fit_transform(np.array(dff).reshape(-1,1))
print(dff)
# Out:
# [[0.16584967]
#  [0.16319444]
#  [0.1621732 ]
#  ...
#  [0.62622549]
#  [0.62214052]
#  [0.62418301]]

# %% [markdown]
# # Spliting the Dataset

# %%
training_size = int(len(dff)*0.70)
test_size = len(dff)-training_size
train_data,test_data=dff[0:training_size,:],dff[training_size:len(dff),:1]

# %% [markdown]
# #Converting an Array of values into a Dataset matrix

# %%
def create_dataset(data, time_step=1):
    dataX, dataY = [], []
    for i in range(len(data)-time_step-1):
        a = data[i:(i+time_step), 0]   
        dataX.append(a)
        dataY.append(data[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# #Spliting the Data into Train and Test

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1323, 100)
# (1323,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (510, 100)
# (510,)
# (None, None)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %% [markdown]
# #Creating the stacked LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 100, 50)           10400
#
#  lstm_4 (LSTM)               (None, 100, 50)           20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_split=0.1,epochs=60,batch_size=64,verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 15s 316ms/step - loss: 0.0104 - val_loss: 0.0013
# Epoch 2/60
# 19/19 [==============================] - 4s 204ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 3/60
# 19/19 [==============================] - 4s 206ms/step - loss: 9.7546e-04 - val_loss: 0.0012
# Epoch 4/60
# 19/19 [==============================] - 4s 205ms/step - loss: 8.2489e-04 - val_loss: 0.0011
# Epoch 5/60
# 19/19 [==============================] - 4s 203ms/step - loss: 7.9107e-04 - val_loss: 0.0011
# Epoch 6/60
# 19/19 [==============================] - 4s 202ms/step - loss: 7.9717e-04 - val_loss: 0.0010
# Epoch 7/60
# 19/19 [==============================] - 4s 204ms/step - loss: 7.4712e-04 - val_loss: 0.0010
# Epoch 8/60
# 19/19 [==============================] - 4s 202ms/step - loss: 7.2774e-04 - val_loss: 9.2226e-04
# Epoch 9/60
# 19/19 [==============================] - 4s 204ms/step - loss: 7.0541e-04 - val_loss: 9.3508e-04
# Epoch 10/60
# 19/19 [==============================] - 4s 200ms/step - loss: 6.9639e-04 - val_loss: 8.9848e-04
# Epoch 11/60
# 19/19 [==============================] - 4s 205ms/step - loss: 6.7690e-04 - val_loss: 7.9997e-04
# Epoch 12/60
# 19/19 [==============================] - 4s 207ms/step - loss: 6.8840e-04 - val_loss: 7.5149e-04
# Epoch 13/60
# 19/19 [==============================] - 4s 207ms/step - loss: 6.2395e-04 - val_loss: 8.0696e-04
# Epoch 14/60
# 19/19 [==============================] - 4s 202ms/step - loss: 6.0874e-04 - val_loss: 7.0482e-04
# Epoch 15/60
# 19/19 [==============================] - 4s 204ms/step - loss: 6.0351e-04 - val_loss: 7.4568e-04
# Epoch 16/60
# 19/19 [==============================] - 4s 201ms/step - loss: 5.8846e-04 - val_loss: 6.6308e-04
# Epoch 17/60
# 19/19 [==============================] - 4s 200ms/step - loss: 5.7766e-04 - val_loss: 6.7926e-04
# Epoch 18/60
# 19/19 [==============================] - 4s 200ms/step - loss: 5.4349e-04 - val_loss: 5.9149e-04
# Epoch 19/60
# 19/19 [==============================] - 4s 204ms/step - loss: 5.2913e-04 - val_loss: 5.9089e-04
# Epoch 20/60
# 19/19 [==============================] - 4s 206ms/step - loss: 5.2982e-04 - val_loss: 6.5690e-04
# Epoch 21/60
# 19/19 [==============================] - 4s 205ms/step - loss: 5.1799e-04 - val_loss: 5.5256e-04
# Epoch 22/60
# 19/19 [==============================] - 4s 205ms/step - loss: 4.9691e-04 - val_loss: 6.6370e-04
# Epoch 23/60
# 19/19 [==============================] - 4s 203ms/step - loss: 5.1099e-04 - val_loss: 5.9437e-04
# Epoch 24/60
# 19/19 [==============================] - 5s 263ms/step - loss: 5.6576e-04 - val_loss: 5.4832e-04
# Epoch 25/60
# 19/19 [==============================] - 5s 239ms/step - loss: 4.7695e-04 - val_loss: 5.9109e-04
# Epoch 26/60
# 19/19 [==============================] - 4s 204ms/step - loss: 4.5409e-04 - val_loss: 5.5220e-04
# Epoch 27/60
# 19/19 [==============================] - 4s 203ms/step - loss: 4.4779e-04 - val_loss: 4.8757e-04
# Epoch 28/60
# 19/19 [==============================] - 4s 207ms/step - loss: 4.4459e-04 - val_loss: 4.2661e-04
# Epoch 29/60
# 19/19 [==============================] - 4s 199ms/step - loss: 4.4005e-04 - val_loss: 4.1269e-04
# Epoch 30/60
# 19/19 [==============================] - 4s 203ms/step - loss: 4.3698e-04 - val_loss: 4.2263e-04
# Epoch 31/60
# 19/19 [==============================] - 4s 205ms/step - loss: 3.7931e-04 - val_loss: 4.1090e-04
# Epoch 32/60
# 19/19 [==============================] - 4s 200ms/step - loss: 3.7005e-04 - val_loss: 3.5945e-04
# Epoch 33/60
# 19/19 [==============================] - 4s 200ms/step - loss: 3.5923e-04 - val_loss: 3.8166e-04
# Epoch 34/60
# 19/19 [==============================] - 4s 203ms/step - loss: 3.5386e-04 - val_loss: 3.2952e-04
# Epoch 35/60
# 19/19 [==============================] - 4s 204ms/step - loss: 3.3481e-04 - val_loss: 3.0978e-04
# Epoch 36/60
# 19/19 [==============================] - 4s 206ms/step - loss: 3.2141e-04 - val_loss: 3.0823e-04
# Epoch 37/60
# 19/19 [==============================] - 4s 202ms/step - loss: 3.1044e-04 - val_loss: 2.8045e-04
# Epoch 38/60
# 19/19 [==============================] - 4s 203ms/step - loss: 3.1296e-04 - val_loss: 2.9872e-04
# Epoch 39/60
# 19/19 [==============================] - 4s 213ms/step - loss: 3.2811e-04 - val_loss: 2.8175e-04
# Epoch 40/60
# 19/19 [==============================] - 4s 202ms/step - loss: 2.8846e-04 - val_loss: 2.5102e-04
# Epoch 41/60
# 19/19 [==============================] - 4s 203ms/step - loss: 2.8166e-04 - val_loss: 2.6948e-04
# Epoch 42/60
# 19/19 [==============================] - 4s 203ms/step - loss: 3.1191e-04 - val_loss: 3.9203e-04
# Epoch 43/60
# 19/19 [==============================] - 4s 206ms/step - loss: 3.2759e-04 - val_loss: 2.8285e-04
# Epoch 44/60
# 19/19 [==============================] - 4s 204ms/step - loss: 2.8875e-04 - val_loss: 2.4722e-04
# Epoch 45/60
# 19/19 [==============================] - 4s 200ms/step - loss: 2.4415e-04 - val_loss: 2.6340e-04
# Epoch 46/60
# 19/19 [==============================] - 4s 207ms/step - loss: 2.5764e-04 - val_loss: 2.1219e-04
# Epoch 47/60
# 19/19 [==============================] - 5s 276ms/step - loss: 2.3724e-04 - val_loss: 2.1777e-04
# Epoch 48/60
# 19/19 [==============================] - 4s 202ms/step - loss: 2.2849e-04 - val_loss: 2.2034e-04
# Epoch 49/60
# 19/19 [==============================] - 4s 200ms/step - loss: 2.3496e-04 - val_loss: 2.2194e-04
# Epoch 50/60
# 19/19 [==============================] - 4s 206ms/step - loss: 2.1871e-04 - val_loss: 1.8383e-04
# Epoch 51/60
# 19/19 [==============================] - 4s 204ms/step - loss: 2.1694e-04 - val_loss: 1.8543e-04
# Epoch 52/60
# 19/19 [==============================] - 4s 208ms/step - loss: 2.1673e-04 - val_loss: 1.7604e-04
# Epoch 53/60
# 19/19 [==============================] - 4s 203ms/step - loss: 2.4522e-04 - val_loss: 1.8431e-04
# Epoch 54/60
# 19/19 [==============================] - 4s 209ms/step - loss: 2.3176e-04 - val_loss: 1.8159e-04
# Epoch 55/60
# 19/19 [==============================] - 4s 209ms/step - loss: 2.2278e-04 - val_loss: 1.6658e-04
# Epoch 56/60
# 19/19 [==============================] - 4s 204ms/step - loss: 2.1127e-04 - val_loss: 2.0614e-04
# Epoch 57/60
# 19/19 [==============================] - 4s 201ms/step - loss: 1.8123e-04 - val_loss: 1.5866e-04
# Epoch 58/60
# 19/19 [==============================] - 4s 207ms/step - loss: 1.7923e-04 - val_loss: 1.6417e-04
# Epoch 59/60
# 19/19 [==============================] - 4s 203ms/step - loss: 2.0336e-04 - val_loss: 1.9431e-04
# Epoch 60/60
# 19/19 [==============================] - 4s 207ms/step - loss: 1.8886e-04 - val_loss: 1.9976e-04

# %% [markdown]
# # Prediction and Checking Performance

# %%
test_predict=model.predict(X_test)

# %%
test_predicted=scaler.inverse_transform(test_predict)
test_predicted
# Out:
# array([[143.69951 ],
#        [143.83476 ],
#        [142.66052 ],
#        [139.53822 ],
#        [138.23488 ],
#        [138.16072 ],
#        [139.86098 ],
#        [141.47794 ],
#        [141.36429 ],
#        [140.62297 ],
#        [140.39427 ],
#        [142.04419 ],
#        [142.79802 ],
#        [144.53569 ],
#        [146.88445 ],
#        [143.68771 ],
#        [141.08818 ],
#        [141.48454 ],
#        [142.59546 ],
#        [148.81712 ],
#        [152.94003 ],
#        [154.1171  ],
#        [153.77913 ],
#        [151.16646 ],
#        [151.72833 ],
#        [151.80862 ],
#        [152.46837 ],
#        [154.50294 ],
#        [154.88545 ],
#        [154.54185 ],
#        [154.99599 ],
#        [153.43379 ],
#        [149.63164 ],
#        [143.36208 ],
#        [140.72066 ],
#        [140.59056 ],
#        [141.01094 ],
#        [139.68423 ],
#        [136.67662 ],
#        [132.48206 ],
#        [130.30238 ],
#        [129.62009 ],
#        [127.35067 ],
#        [126.78725 ],
#        [124.434074],
#        [121.563934],
#        [121.357895],
#        [121.28693 ],
#        [121.66832 ],
#        [120.36906 ],
#        [119.3725  ],
#        [119.067154],
#        [118.19379 ],
#        [118.5459  ],
#        [120.22623 ],
#        [122.15376 ],
#        [124.05645 ],
#        [124.44773 ],
#        [123.829765],
#        [123.85371 ],
#        [124.12808 ],
#        [123.97266 ],
#        [124.29375 ],
#        [124.79735 ],
#        [124.98795 ],
#        [124.988976],
#        [124.724556],
#        [125.12697 ],
#        [125.64114 ],
#        [125.966736],
#        [124.90363 ],
#        [123.796974],
#        [122.36181 ],
#        [121.149704],
#        [119.85662 ],
#        [120.337006],
#        [121.09114 ],
#        [122.11436 ],
#        [123.16182 ],
#        [124.33599 ],
#        [125.39657 ],
#        [125.925644],
#        [126.25004 ],
#        [126.14322 ],
#        [125.92372 ],
#        [125.66244 ],
#        [126.720924],
#        [127.048134],
#        [128.12843 ],
#        [128.90884 ],
#        [129.1916  ],
#        [129.59091 ],
#        [130.6577  ],
#        [129.92003 ],
#        [129.28925 ],
#        [129.31013 ],
#        [129.57314 ],
#        [130.16187 ],
#        [131.16112 ],
#        [131.25493 ],
#        [131.40785 ],
#        [134.68819 ],
#        [139.70547 ],
#        [143.48535 ],
#        [144.39697 ],
#        [145.71086 ],
#        [145.62569 ],
#        [144.99075 ],
#        [143.62642 ],
#        [142.4073  ],
#        [140.8643  ],
#        [140.69882 ],
#        [141.31496 ],
#        [142.65157 ],
#        [143.65262 ],
#        [143.26756 ],
#        [142.1578  ],
#        [141.14258 ],
#        [140.24014 ],
#        [142.33057 ],
#        [143.42136 ],
#        [144.49509 ],
#        [145.01407 ],
#        [144.7805  ],
#        [143.71915 ],
#        [142.5901  ],
#        [140.31323 ],
#        [139.85123 ],
#        [141.05638 ],
#        [144.07631 ],
#        [146.3783  ],
#        [147.97614 ],
#        [148.23053 ],
#        [146.4534  ],
#        [148.86316 ],
#        [151.53423 ],
#        [151.5377  ],
#        [151.51836 ],
#        [151.64587 ],
#        [151.5576  ],
#        [151.68045 ],
#        [152.56676 ],
#        [153.70174 ],
#        [154.55368 ],
#        [153.61513 ],
#        [152.72278 ],
#        [153.63591 ],
#        [153.87492 ],
#        [153.0615  ],
#        [151.80911 ],
#        [150.44426 ],
#        [150.82191 ],
#        [152.63725 ],
#        [153.53606 ],
#        [153.9001  ],
#        [153.7391  ],
#        [154.48492 ],
#        [154.28156 ],
#        [154.30522 ],
#        [156.81036 ],
#        [158.07288 ],
#        [157.67674 ],
#        [155.34993 ],
#        [153.82782 ],
#        [154.26009 ],
#        [155.60234 ],
#        [156.10953 ],
#        [155.36058 ],
#        [155.63058 ],
#        [156.055   ],
#        [155.41267 ],
#        [151.9538  ],
#        [150.45508 ],
#        [149.67384 ],
#        [147.99023 ],
#        [145.38927 ],
#        [144.54129 ],
#        [146.67508 ],
#        [148.01093 ],
#        [148.30305 ],
#        [149.90427 ],
#        [152.59732 ],
#        [155.39189 ],
#        [156.68495 ],
#        [155.64665 ],
#        [155.6134  ],
#        [155.54138 ],
#        [155.40573 ],
#        [154.2326  ],
#        [155.70084 ],
#        [158.5129  ],
#        [160.61932 ],
#        [160.83379 ],
#        [159.30515 ],
#        [158.28201 ],
#        [158.01167 ],
#        [157.06453 ],
#        [154.534   ],
#        [150.95529 ],
#        [150.00534 ],
#        [150.21773 ],
#        [151.78503 ],
#        [153.46474 ],
#        [153.40242 ],
#        [155.78093 ],
#        [156.25398 ],
#        [157.87073 ],
#        [163.66689 ],
#        [169.30498 ],
#        [173.87    ],
#        [176.25919 ],
#        [175.6719  ],
#        [176.0677  ],
#        [174.71579 ],
#        [174.60225 ],
#        [172.91588 ],
#        [172.55656 ],
#        [171.78287 ],
#        [172.20474 ],
#        [173.49448 ],
#        [171.97678 ],
#        [170.9422  ],
#        [170.92833 ],
#        [169.92934 ],
#        [167.74675 ],
#        [167.42723 ],
#        [167.7525  ],
#        [170.36449 ],
#        [169.45186 ],
#        [165.59698 ],
#        [159.6938  ],
#        [161.38158 ],
#        [172.981   ],
#        [190.00342 ],
#        [196.12634 ],
#        [196.56862 ],
#        [195.71416 ],
#        [190.51454 ],
#        [192.03851 ],
#        [193.25273 ],
#        [193.21445 ],
#        [191.28001 ],
#        [195.07861 ],
#        [198.65154 ],
#        [199.33157 ],
#        [195.6775  ],
#        [195.76926 ],
#        [203.24356 ],
#        [207.03015 ],
#        [207.6497  ],
#        [208.4698  ],
#        [210.5323  ],
#        [207.65915 ],
#        [209.21576 ],
#        [209.648   ],
#        [211.57903 ],
#        [214.66515 ],
#        [213.70851 ],
#        [211.3265  ],
#        [202.11626 ],
#        [195.3219  ],
#        [200.57414 ],
#        [200.57951 ],
#        [202.78662 ],
#        [205.82454 ],
#        [206.98705 ],
#        [205.40057 ],
#        [207.4089  ],
#        [208.72276 ],
#        [207.77032 ],
#        [207.09206 ],
#        [207.7513  ],
#        [210.2494  ],
#        [210.03128 ],
#        [208.8752  ],
#        [208.96733 ],
#        [206.70566 ],
#        [204.07689 ],
#        [202.42412 ],
#        [207.2819  ],
#        [206.85143 ],
#        [208.76562 ],
#        [217.72723 ],
#        [226.03099 ],
#        [227.31348 ],
#        [226.03052 ],
#        [223.64336 ],
#        [221.99431 ],
#        [229.56372 ],
#        [225.35445 ],
#        [221.7972  ],
#        [234.44604 ],
#        [236.58595 ],
#        [232.9711  ],
#        [241.16556 ],
#        [248.0285  ],
#        [249.13548 ],
#        [254.47873 ],
#        [268.4884  ],
#        [269.3223  ],
#        [266.8952  ],
#        [266.2119  ],
#        [269.8475  ],
#        [269.64746 ],
#        [278.64087 ],
#        [273.16104 ],
#        [276.9294  ],
#        [274.85013 ],
#        [269.5113  ],
#        [269.89545 ],
#        [266.26306 ],
#        [274.4733  ],
#        [280.70575 ],
#        [289.5396  ],
#        [279.05447 ],
#        [272.22882 ],
#        [272.57367 ],
#        [276.5573  ],
#        [281.3638  ],
#        [290.88513 ],
#        [291.2322  ],
#        [288.4423  ],
#        [289.9834  ],
#        [293.4599  ],
#        [293.13873 ],
#        [293.50577 ],
#        [303.1238  ],
#        [300.25467 ],
#        [296.5289  ],
#        [296.383   ],
#        [298.00894 ],
#        [299.03217 ],
#        [303.58008 ],
#        [301.27667 ],
#        [299.058   ],
#        [298.275   ],
#        [311.1084  ],
#        [309.14746 ],
#        [300.17465 ],
#        [296.6914  ],
#        [289.72736 ],
#        [293.49667 ],
#        [295.8356  ],
#        [294.2082  ],
#        [290.83746 ],
#        [290.81946 ],
#        [288.97354 ],
#        [291.22455 ],
#        [278.506   ],
#        [275.1337  ],
#        [263.87457 ],
#        [262.40433 ],
#        [258.6202  ],
#        [271.83054 ],
#        [274.99283 ],
#        [271.06778 ],
#        [275.79852 ],
#        [273.69608 ],
#        [269.6493  ],
#        [266.02167 ],
#        [259.08618 ],
#        [254.26126 ],
#        [258.6809  ],
#        [256.7326  ],
#        [263.83624 ],
#        [268.08304 ],
#        [268.7868  ],
#        [268.15958 ],
#        [266.8709  ],
#        [267.2842  ],
#        [266.17123 ],
#        [261.0917  ],
#        [264.73807 ],
#        [261.77618 ],
#        [267.99283 ],
#        [271.664   ],
#        [271.39127 ],
#        [271.3895  ],
#        [264.32983 ],
#        [252.00838 ],
#        [252.72583 ],
#        [256.64435 ],
#        [253.92079 ],
#        [252.05148 ],
#        [256.      ],
#        [258.5678  ],
#        [253.6919  ],
#        [268.46805 ],
#        [270.34195 ],
#        [263.50052 ],
#        [263.82153 ],
#        [264.60297 ],
#        [269.61337 ],
#        [268.4254  ],
#        [265.774   ],
#        [265.428   ],
#        [267.4318  ],
#        [271.86905 ],
#        [273.5308  ],
#        [275.81882 ],
#        [277.56747 ],
#        [277.23364 ],
#        [274.05203 ],
#        [273.07623 ],
#        [279.1928  ],
#        [282.37527 ],
#        [282.60416 ],
#        [287.0211  ],
#        [282.54745 ],
#        [275.12003 ],
#        [276.02    ],
#        [283.81635 ],
#        [280.6377  ],
#        [281.22595 ],
#        [275.02386 ],
#        [276.3583  ],
#        [247.22705 ],
#        [231.41327 ],
#        [233.12012 ],
#        [243.28012 ],
#        [243.68596 ],
#        [241.00822 ],
#        [242.91898 ],
#        [246.08131 ],
#        [249.98587 ],
#        [253.03178 ],
#        [255.1966  ],
#        [252.03969 ],
#        [256.90265 ],
#        [262.89514 ],
#        [258.06793 ],
#        [248.56606 ],
#        [255.07645 ],
#        [260.4924  ],
#        [262.10837 ],
#        [261.26364 ],
#        [257.5148  ],
#        [260.25415 ],
#        [263.32874 ],
#        [271.02036 ],
#        [266.60773 ],
#        [266.96335 ],
#        [259.75168 ],
#        [252.61179 ],
#        [250.37341 ],
#        [255.27274 ],
#        [259.35193 ],
#        [262.05722 ],
#        [260.00775 ],
#        [257.17517 ],
#        [261.62534 ],
#        [258.50113 ],
#        [272.2447  ],
#        [272.06628 ],
#        [263.63223 ],
#        [257.07285 ],
#        [265.6448  ],
#        [268.37335 ],
#        [263.05774 ],
#        [257.23798 ],
#        [251.2385  ],
#        [237.11856 ],
#        [240.10356 ],
#        [235.68692 ],
#        [229.83458 ],
#        [234.1722  ],
#        [240.5957  ],
#        [244.10191 ],
#        [235.37115 ],
#        [233.59163 ],
#        [237.25075 ],
#        [238.74892 ],
#        [242.61426 ],
#        [233.8003  ],
#        [230.19159 ],
#        [230.30247 ],
#        [235.48816 ],
#        [235.81796 ],
#        [233.8708  ],
#        [233.88483 ],
#        [231.04115 ],
#        [230.98271 ],
#        [234.14146 ],
#        [236.76057 ],
#        [239.99649 ],
#        [242.13605 ],
#        [237.9622  ],
#        [231.68552 ],
#        [226.83861 ],
#        [231.94363 ],
#        [231.86298 ],
#        [232.02095 ],
#        [233.29886 ],
#        [232.12791 ],
#        [233.35718 ],
#        [223.05359 ],
#        [218.3358  ],
#        [217.9487  ],
#        [220.66367 ],
#        [221.2549  ],
#        [216.12166 ],
#        [219.26913 ],
#        [230.55339 ],
#        [236.21803 ],
#        [234.18387 ],
#        [231.54622 ],
#        [230.44194 ],
#        [229.5325  ],
#        [232.005   ],
#        [231.79396 ]], dtype=float32)

# %% [markdown]
# # Calculating the Performance

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
performance = math.sqrt(mean_squared_error(ytest,test_predict))
performance
# Out:
# 0.029068967427350406
